# %% [markdown]
# # Kasra Tutorial

# %% [markdown]
# ### Libs

# %%
import torch
from torchvision import transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %% [markdown]
# ### Custom Dataset

# %%
from dataset.CustomDataLoader import CustomDataLoader

# %%
root_fmri =
root_image =
self_ROI_array = 
nsd_subj01_08_id_img =

# %%
# transform
trans=transforms.Compose([
    transforms.ToTensor(),
    transforms.ConvertImageDtype(torch.float),
    transforms.Normalize((0.5,) , (0.5,))
])

# dataset
"""
dataset = CustomDataLoader(fmri_file = './data/fmri/sub-01_perceptionNaturalImageTraining_original_VC.h5',
                            imagenet_folder= './data/images/training',
                           transform=trans)
"""


dataset = CustomDataLoader(root_fmri, root_image, self_ROI_array, nsd_subj01_08_id_img, transform=trans)

# dataloader
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

# %% [markdown]
# ### Test Outputs

# %%
for image_data, fmri_data in dataloader:
    image_data = image_data
    fmri_data = fmri_data
    print(image_data.shape)
    print(fmri_data.shape)
# Out:
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# torch.Size([1, 11726])
# torch.Size([1, 3, 500, 500])
# ...

# %%
for _, fmri_data in dataloader:
    fmri_data = fmri_data
    if not(fmri_data.shape == torch.Size([1, 11726]))
        print("erorr")

# %%
for _, fmri_data in dataloader:
    fmri_data = fmri_data
    if not(fmri_data.shape == torch.Size([1, 11726])):
        print("Error")

# %%
# Test Size
print("image_data Shape:")
print(image_data.shape)
print("fmri_data Shape:")
print(fmri_data.shape)
# Out:
# image_data Shape:
# torch.Size([100, 3, 500, 500])
# fmri_data Shape:
# torch.Size([100, 11726])

# %%
# Imshow one sample of image_data
plt.imshow(image_data[10].permute(2,1,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Imshow one sample of image_data[:100]
plt.plot(fmri_data[0][-100:])
